# %%
import pandas as pd
import folium as folium
from folium.plugins import Geocoder
from folium.plugins import MousePosition

# %%
#initializes the map focused on Abilene Tx 
m = folium.Map(location=[32.4487, -99.7331], zoom_start=12)

#icon presets for categories
icon_settings = {
    "gro": {"prefix": "fa", "icon": "shopping-basket", "color": "green"},
    "med": {"prefix": "fa", "icon": "plus-square", "color": "red"},
    "den": {"prefix": "fa", "icon": "smile", "color": "purple"},
    "gov": {"prefix": "fa", "icon": "university", "color": "black"},
    "clo": {"prefix": "fa", "icon": "shirt", "color": "orange"},
    "lib": {"prefix": "fa", "icon": "book", "color": "blue"}
}

#definition for repetitive additions
def add_marker(group, location, icon_type, popup, tooltip):
    folium.Marker(
        location=location,
        icon=folium.Icon(**icon_type),
        popup=popup,
        tooltip=tooltip
    ).add_to(group)


#grouping by category (may have to add the add_to(m) section at the end to apply)
group_1 = folium.FeatureGroup("Grocery").add_to(m)
group_2 = folium.FeatureGroup(name="Medical").add_to(m)
group_3 = folium.FeatureGroup(name="Dental").add_to(m)
group_4 = folium.FeatureGroup(name="Government").add_to(m)
group_5 = folium.FeatureGroup(name="Clothing").add_to(m)
group_6 = folium.FeatureGroup(name="Library").add_to(m)

#=================================================================================================================================================================
# Markers on the map
#=================================================================================================================================================================

#group 1: groceries
add_marker(group_1, [32.46100432967644, -99.75976423054549], icon_settings["gro"], '<a href="https://www.cscabilene.org/" target="_blank">Website</a>', "Christian Service Center")
add_marker(group_1, [32.47099396842267, -99.75804984772674], icon_settings["gro"], '<a href="https://www.facebook.com/crescentheightsbaptistchurchabilene/" target="_blank">Facebook</a>', "Crescent Heights Baptist Church")
add_marker(group_1, [32.4464375188334, -99.74937763423273], icon_settings["gro"], '<a href="https://www.highlandchurch.org/pantry//" target="_blank">Website</a>', "Highland Church of Christ")
add_marker(group_1, [32.45290887481718, -99.75666483423245], icon_settings["gro"], '<a href="https://lcmin.com/" target="_blank">Website</a>', "Love & Care Ministries")
add_marker(group_1, [32.45481301802139, -99.79475939005708], icon_settings["gro"], '<a href="https://fbwct.org/" target="_blank">Website</a>', "Food Bank of Abilene INC.")
add_marker(group_1, [32.352502806409454, -99.773530049422], icon_settings["gro"], '<a href="https://beltway.org/ministries/care-support/food-pantry/">Website</a>', "Beltway Park Church (South)")
add_marker(group_1, [32.495663757483385, -99.66915994188255], icon_settings["gro"], '<a href="https://beltway.org/ministries/care-support/food-pantry/">Website</a>', "Beltway Park Church (North)")
add_marker(group_1, [32.445083545103145, -99.78023836458364], icon_settings["gro"], '<a href="https://homelessresources.networkofcare.org/texas/services/agency?pid=AbileneBaptistSocialMinistriesABSMFoodPantries_21_1756_1" target="_blank">Information</a>', "Abilene Baptist Social Ministries Food Pantry")
add_marker(group_1, [32.44425877423999, -99.74524801591576], icon_settings["gro"], '<a href="https://www.heavenlyrestabilene.org/" target="_blank">Website</a>', "Heavenly Rest Church Food Pantry")
add_marker(group_1, [32.4529018009577, -99.73744033054157], icon_settings["gro"], '<a href="https://fcpc.net/serve/presbyterian-food-pantry" target="_blank">Website</a>', "Presbyterian Food Pantry")
add_marker(group_1, [32.45145557115808, -99.75392958665454], icon_settings["gro"], '<a href="https://methodist-pantry.edan.io/" target="_blank">Info</a>', "United Methodist Food Pantry")
add_marker(group_1, [32.44110657366847, -99.74245449617045], icon_settings["gro"], '<a href="https://www.sacredheartabilene.org/" target="_blank">Website</a>', "Sacred Heart Catholic Church")
add_marker(group_1, [32.461340828932336, -99.74704596122186], icon_settings["gro"], '<a href="https://www.foodpantries.org/li/bethlehem_pa-Abilen-79603" target="_blank">Website</a>', "Bethlehem Pantry")
add_marker(group_1, [32.44471569816194, -99.79420516700566], icon_settings["gro"], '<a href="http://www.allforonemissions.org/food" target="_blank">Website</a>', "All for One Missions Food Pantry")
add_marker(group_1, [32.45979455530402, -99.78851168815052], icon_settings["gro"], '<a href="https://www.facebook.com/holidayhillsbc/" target="_blank">Facebook</a>', "Holidays Hills Baptist Church Pantry")
add_marker(group_1, [32.44380097482554, -99.71148219674683], icon_settings["gro"], '<a href="https://www.facebook.com/mindastreet.coc/" target="_blank">Facebook</a>', "Minda Street Church of Christ Food")
add_marker(group_1, [32.444914173586746, -99.79694612500536], icon_settings["gro"], '<a href="https://www.facebook.com/VictoryHouseAB/" target="_blank">Facebook</a>', "The RCCG Victory House")
add_marker(group_1, [32.413610937692674, -99.75244547866221], icon_settings["gro"], '<a href="https://wearesouthpointe.churchcenter.com/home" target="_blank">Website</a>', "South Pointe Church Food Pantry")
add_marker(group_1, [32.483244355902585, -99.74893674382714], icon_settings["gro"], '<a href="https://stvincent-pallotti.org/" target="_blank">Website</a>', "St Vincent Pallotti Catholic Church")
add_marker(group_1, [32.416771413455315, -99.79381885257239], icon_settings["gro"], '<a href="https://www.facebook.com/p/Faith-Deliverance-Community-Church-100064439479525/" target="_blank">Facebook</a>', "Faith Deliverance Community Church")
add_marker(group_1, [32.44158713611253, -99.75450405995348], icon_settings["gro"], '<a href="https://abilenetx.gov/facilities/facility/details/Rose-Park-Senior-Activity-Center-53" target="_blank">Website</a>', "Rose Park Senior Center")
add_marker(group_1, [32.45274620808027, -99.73798694588183], icon_settings["gro"], '<a href="https://fcpc.net/serve/bobs-breakfast-on-beech-street" target="_blank">Website</a>', "Breakfast on Beech Street (B.O.B.S)")
add_marker(group_1, [32.45635584448183, -99.73812148463117], icon_settings["gro"], '<a href="https://www.facebook.com/FirstBaptistChurchAbilene/" target="_blank">Facebook</a>', "City Light Ministries")
add_marker(group_1, [32.46463061056373, -99.73909623931897], icon_settings["gro"], '<a href="https://www.facebook.com/Church.on.the.Rock.Abilene/" target="_blank">Facebook</a>', "Church on the Rock")


#group 2: medical
add_marker(group_2, [32.454995, -99.735798], icon_settings["med"], "Medical Center", "Medical Center")


#group 3: dental
add_marker(group_3, [32.4654, -99.7314], icon_settings["den"], '<a href="https://www.smartfamilydentistry.com/schedule-form/" target="_blank">Schedule an Appointment</a>', "Smart Family Dentistry")


#group 4: government
add_marker(group_4, [32.45399193774133, -99.73097549559823], icon_settings["gov"], '<a href="https://abilenetx.gov/facilities/facility/details/Abilene-City-Hall-85abilene " target="_blank">Website</a>', "City Hall")
add_marker(group_4, [32.44931550112866, -99.78188654844233], icon_settings["gov"], '<a href="https://www.abilenetx.gov/275/Municipal-Court" target="_blank">Website</a>', "Abilene Municipal Courts")
add_marker(group_4, [32.44674868205182, -99.73248476606938], icon_settings["gov"], '<a href="https://www.taylorcounty.texas.gov/204/County-Courts-at-Law" target="_blank">Info</a>', "Taylor County Courthouse")
add_marker(group_4, [32.4968399358427, -99.64642532740997], icon_settings["gov"], '<a href="https://www.dps.texas.gov/" target="_blank">Website</a>', "Texas Dept. of Public Safety")
add_marker(group_4, [32.46027105081111, -99.78412632848287], icon_settings["gov"], '<a href="https://www.hhs.texas.gov/" target="_blank">Website</a>', "Health & Human Services")
add_marker(group_4, [32.456573575820805, -99.72479949186392], icon_settings["gov"], '<a href="https://abilenetx.gov/159/Public-Health" target="_blank">Website</a>', "Health Dept.")
add_marker(group_4, [32.446511324781206, -99.72674437458245], icon_settings["gov"], '<a href="https://www.taylorcounty.texas.gov/185/Motor-Vehicle-Registration" target="_blank">Website</a>', "Motor Vehicle Registration")
add_marker(group_4, [32.43818724141249, -99.70394489432898], icon_settings["gov"], '<a href="https://www.ssa.gov/" target="_blank">Website</a>', "Social Security Office")
add_marker(group_4, [32.46706974026797, -99.59636472632224], icon_settings["gov"], '<a href="https://wfswct.org/" target="_blank">Website</a>', "Workforce Solutions of W. Central Texas")



#group 5: clothing
add_marker(group_5, [32.454995, -99.73], icon_settings["clo"], "Clothing Store", "Clothing Store")


#group 6: Libraries
add_marker(group_6, [32.4220, -99.7353], icon_settings["lib"], "South Branch Public Library", "South Branch Public Library")
add_marker(group_6, [32.4697, -99.7334], icon_settings["lib"], "Mockingbird Public Library", "Mockingbird Public Library")
add_marker(group_6, [32.4489, -99.7330], icon_settings["lib"], "Abilene Public Library", "Abilene Public Library")


#=================================================================================================================================================================
# Add ons 
#=================================================================================================================================================================


#adds address search bar to map
folium.plugins.Geocoder().add_to(m)

#adds layer control to map
folium.LayerControl().add_to(m)

#Determines user location
folium.plugins.LocateControl(auto_start=False).add_to(m)

#mouse hover shows coordinates
MousePosition().add_to(m)

#=================================================================================================================================================================
# Deploy
#=================================================================================================================================================================

#saves html output
m.save("map.html")

#Map Output
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
